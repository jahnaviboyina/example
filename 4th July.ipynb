# %%
# Graph to plot distance and time
distance= list(range(2,11,2))
time= list(range(1,6))
 # d=2*t
plt.title('Distance VS Time')
plt.xlabel('Time')
plt.ylabel('Distance')
plt.plot(time,distance,'bo')
plt.grid()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[1,2,3])
plt.show()

# %%
# v=a t
t=list(range(1,11))
v= [2*i for i in t]
plt.plot(t,v)
plt.grid()
plt.show()

# %%
# v=a t
t=list(range(1,11))
a=list(range(len(t)+1))
v= [a[i]*i for i in range(len(t))]
plt.plot(t,v)
plt.grid()
plt.show()

# %%
n=list(range(10))
sq=[i**100 for i in n]
plt.plot(n,sq)
plt.grid()

# %%
# Voltage=Time
import numpy as np
t=np.arange(0.1,2.0,0.1)
v=[1+np.sin(2*np.pi*i) for i in t]
plt.title('Time VS voltage')
plt.plot(t,v)
plt.xlabel("Time")
plt.ylabel("Voltage")
plt.grid()
plt.savefig('Images/Voltage-Time.png')

# %%
# Plot Income of Arkansas from 2005 to 2013
import pandas as pd
df=pd.read_csv('Datafiles/Income.csv')
years=df.columns[2:]
incomeArkansas=df.values[3,2:]
plt.title('Income of Arkansas')
plt.xlabel('Year')
plt.ylabel('Income')
plt.plot(years,incomeArkansas)

# %%
# Income of all states from 2005 to 2013
incomeallstates=[]
df
for i in df.columns[2:]:
    incomeallstates.append(df[i].mean())
plt.plot(years,incomeallstates)
plt.title('All states income')
plt.xlabel('year')
plt.ylabel('Income')
plt.grid()

# %%
applestore=readcsv(filepath)
def getcolumnindex(df,columnkey):
    for i in range(len(df.columns)):
        if(df.columns[i]==columnkey):
            columnindex=i
    return columnindex
def prime_genre():
    li=[]
    uni=[]
    c=getcolumnindex(applestore,'prime_genre')
    for i in range(len(applestore.columns)):
        li.append(applestore.values[i][c])
    for i in li:
        if i not in uni:
            uni.append(i)
    print(uni)
    
prime_genre()
# Out:
# ['Games', 'Productivity', 'Weather', 'Shopping', 'Reference', 'Finance', 'Music', 'Utilities', 'Travel', 'Social Networking']
# ['Games', 'Productivity', 'Weather', 'Shopping', 'Reference', 'Finance', 'Music', 'Utilities', 'Travel', 'Social Networking']

# %%
import pandas as pd
filepath='Datafiles/AppleStore.csv'
def readcsv(filepath):
    return pd.read_csv(filepath)
readcsv(filepath)
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# 5              6   283619399
# 6              7   283646709
# 7              8   284035177
# 8              9   284666222
# 9             10   284736660
# 10            11   284791396
# 11            12   284815117
# 12            13   284815942
# 13            14   284847138
# 14            15   284862767
# 15            16   284876795
# 16            17   284882215
# 17            18   284910350
# 18            20   284993459
# 19            21   285005463
# 20            22   285946052
# 21            23   285994151
# 22            24   286058814
# 23            25   286070473
# 24            27   286799607
# 25            28   286906691
# 26            29   286911400
# 27            31   288113403
# 28            32   288120394
# 29            33   288419283
# ...          ...         ...
# ...

# %%
# Category with highest number of apps
def highnoapps(applestore):
    li=[]
    for i in range(len(applestore.columns)):
        li.append(applestore.values[i][6])
        c=max(li)
    for i in range(len(li)):
        if(c==applestore.values[i][6]):
            print(applestore.values[i][2])
highnoapps(applestore)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-15f0a7cb67db> in <module>
#       8         if(c==applestore.values[i][6]):
#       9             print(applestore.values[i][2])
# ---> 10 highnoapps(applestore)
#
# NameError: name 'applestore' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-15f0a7cb67db> in <module>
#       8         if(c==applestore.values[i][6]):
#       9             print(applestore.values[i][2])
# ---> 10 highnoapps(applestore)
#
# NameError: name 'applestore' is not defined

# %%
# Category with highest number of apps
def highnoapps(applestore):
    li=[]
    for i in range(len(applestore.columns)):
        li.append(applestore.values[i][6])
        c=min(li)
    for i in range(len(li)):
        if(c==applestore.values[i][6]):
            print(applestore.values[i][2])
highnoapps(applestore)
# Out:
# PCalc - The Best Calculator
# PCalc - The Best Calculator

# %%
def seco(li):
    uni=[]
    for i in range(0,len(li)):
        if li[i] not in uni:
            uni.append(li[i])
    sor=sorted(uni)
    if(len(sor)>1):
        print(sor[-2])
    else:
        return -1
seco([50,100,50])
# Out:
# 50
# 50

# %%
li=[-7,-6]
li[-2]
# Out:
# -7
# -7
